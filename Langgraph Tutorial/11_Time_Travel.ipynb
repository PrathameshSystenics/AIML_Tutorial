# %% [markdown]
# ## Time Travel
#
# When working with graphs, for understanding their decision making helps in understanding:
# - Understanding Reasoning
# - Debug Mistakes
# - Explore Alternatives
#
# Langgraph provides support for Time Travel to support these usecases. Specifically you can resume the execution from the prior checkpoint id. Instead of running all the nodes in the Graph.
#
# In these tutorial we are going to get the chat history change the state and run the graph.

# %%
from langgraph.graph import StateGraph,START,END,MessagesState
from langgraph.checkpoint.memory import InMemorySaver
from langchain_core.runnables import RunnableConfig
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from typing_extensions import TypedDict,NotRequired

load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", include_thoughts=False, temperature=0
)

# %%
class State(TypedDict):
    topic: NotRequired[str]
    joke: NotRequired[str]

# %%
def generate_topic(state: State) -> State:
    """LLM call to generate a topic for the joke"""
    msg = model.invoke("Give me a funny topic for a joke")
    return {"topic": msg.content}


def write_joke(state: State) -> State:
    """LLM call to write a joke based on the topic"""
    msg = model.invoke(f"Write a short joke about {state['topic']}")
    return {"joke": msg.content}

# %%
workflow = StateGraph(State)

# Add nodes
workflow.add_node("generate_topic", generate_topic)
workflow.add_node("write_joke", write_joke)

# Add edges to connect nodes
workflow.add_edge(START, "generate_topic")
workflow.add_edge("generate_topic", "write_joke")
workflow.add_edge("write_joke", END)

# Compile
checkpointer = InMemorySaver()
graph = workflow.compile(checkpointer=checkpointer)

# %% [markdown]
# Run the graph

# %%
import uuid


config: RunnableConfig = {"configurable": {"thread_id": uuid.uuid1()}}

# %%
config
# Out:
# {'configurable': {'thread_id': UUID('8ed777e0-cbb8-11f0-89a1-b48c9d911a92')}}

# %%
state = graph.invoke({}, config)
print(state)
# Out:
# {'topic': 'Okay, here are some funny topics for a joke, ranging from relatable to absurd:\n\n1.  **The existential dread of trying to assemble IKEA furniture.** (Universal frustration, tiny diagrams, missing screws, questioning your life choices.)\n2.  **Autocorrect fails that lead to hilariously inappropriate texts.** (Especially when texting parents or bosses.)\n3.  **Trying to explain technology to your parents/grandparents.** (The "where\'s the any key?" phenomenon, yelling at smart speakers.)\n4.  **The struggle of adulting:** bills, laundry, and pretending you know how to cook. (The sheer exhaustion of basic life tasks.)\n5.  **Your pet\'s secret life when you\'re not home.** (Are they throwing parties? Running a secret society? Judging your life choices?)\n6.  **Smart home devices that constantly misunderstand you.** (Alexa playing death metal when you asked for "smooth jazz.")\n7.  **The agony of trying to remember all your passwords.** (And the ridiculous security questions.)\n8.  **The "reply all" email chain that spirals out of control.** (Especially in a corporate setting.)\n9.  **Trying to open "child-proof" packaging when you\'re an adult.** (And failing miserably.)\n10. **The inner monologue of a pigeon.** (What are they *really* thinking as they stare at you?)\n11. **The endless scroll of streaming services and the inability to choose anything.** (Spending more time browsing than watching.)\n12. **People who talk on speakerphone in public.** (And the bizarre snippets of conversation you overhear.)\n\nChoose one that sparks your imagination! Good luck!', 'joke': 'Here\'s a joke about **Trying to open "child-proof" packaging when you\'re an adult**:\n\n"I\'m convinced \'child-proof\' packaging is actually \'adult-proof.\' My kids can open anything, but I need a search party and a pair of pliers just to get to the Advil."'}

# %%
async for chunk in graph.astream({},config,stream_mode="updates"):
    print(chunk)
# Out:
# {'generate_topic': {'topic': 'Okay, here are some funny topics for a joke, ranging from relatable to absurd:\n\n1.  **The existential dread of trying to assemble IKEA furniture.** (Universal frustration, tiny diagrams, missing screws, questioning your life choices.)\n2.  **Autocorrect fails that lead to hilariously inappropriate texts.** (Especially when texting parents or bosses.)\n3.  **Trying to explain technology to your parents/grandparents.** (The "where\'s the any key?" phenomenon, yelling at smart speakers.)\n4.  **The struggle of adulting:** bills, laundry, and pretending you know how to cook. (The sheer exhaustion of basic life tasks.)\n5.  **Your pet\'s secret life when you\'re not home.** (Are they throwing parties? Running a secret society? Judging your life choices?)\n6.  **Smart home devices that constantly misunderstand you.** (Alexa playing death metal when you asked for "smooth jazz.")\n7.  **The agony of trying to remember all your passwords.** (And the ridiculous security questions.)\n8.  **The "reply all" email chain that spirals out of control.** (Especially in a corporate setting.)\n9.  **Trying to open "child-proof" packaging when you\'re an adult.** (And failing miserably.)\n10. **The inner monologue of a pigeon.** (What are they *really* thinking as they stare at you?)\n11. **The endless scroll of streaming services and the inability to choose anything.** (Spending more time browsing than watching.)\n12. **People who talk on speakerphone in public.** (And the bizarre snippets of conversation you overhear.)\n\nChoose one that sparks your imagination! Good luck!'}}
# {'write_joke': {'joke': 'I asked my smart speaker to play some "relaxing music." It responded, "Playing \'Raining Blood\' by Slayer."\n\nI guess it knows how I *really* feel about Mondays.'}}

# %% [markdown]
# Going back to the history

# %%
from IPython.display import Markdown

states = graph.get_state_history(config)
for state in states:
    print(state.values)
    print("Next = ",state.next)
    print("checkpoint ID = ",state.config["configurable"]["checkpoint_id"])
    print("-----")
# Out:
# {'topic': 'Okay, here are some funny topics for a joke, ranging from relatable to absurd:\n\n1.  **The existential dread of trying to assemble IKEA furniture.** (Universal frustration, tiny diagrams, missing screws, questioning your life choices.)\n2.  **Autocorrect fails that lead to hilariously inappropriate texts.** (Especially when texting parents or bosses.)\n3.  **Trying to explain technology to your parents/grandparents.** (The "where\'s the any key?" phenomenon, yelling at smart speakers.)\n4.  **The struggle of adulting:** bills, laundry, and pretending you know how to cook. (The sheer exhaustion of basic life tasks.)\n5.  **Your pet\'s secret life when you\'re not home.** (Are they throwing parties? Running a secret society? Judging your life choices?)\n6.  **Smart home devices that constantly misunderstand you.** (Alexa playing death metal when you asked for "smooth jazz.")\n7.  **The agony of trying to remember all your passwords.** (And the ridiculous security questions.)\n8.  **The "reply all" email chain that spirals out of control.** (Especially in a corporate setting.)\n9.  **Trying to open "child-proof" packaging when you\'re an adult.** (And failing miserably.)\n10. **The inner monologue of a pigeon.** (What are they *really* thinking as they stare at you?)\n11. **The endless scroll of streaming services and the inability to choose anything.** (Spending more time browsing than watching.)\n12. **People who talk on speakerphone in public.** (And the bizarre snippets of conversation you overhear.)\n\nChoose one that sparks your imagination! Good luck!', 'joke': 'I asked my smart speaker to play some "relaxing music." It responded, "Playing \'Raining Blood\' by Slayer."\n\nI guess it knows how I *really* feel about Mondays.'}
# Next =  ()
# checkpoint ID =  1f0cbb8b-3237-60d8-8006-c36d2df925d6
# -----
# {'topic': 'Okay, here are some funny topics for a joke, ranging from relatable to absurd:\n\n1.  **The existential dread of trying to assemble IKEA furniture.** (Universal frustration, tiny diagrams, missing screws, questioning your life choices.)\n2.  **Autocorrect fails that lead to hilariously inappropriate texts.** (Especially when texting parents or bosses.)\n3.  **Trying to explain technology to your parents/grandparents.** (The "where\'s the any key?" phenomenon, yelling at smart speakers.)\n4.  **The struggle of adulting:** bills, laundry, and pretending you know how to cook. (The sheer exhaustion of basic life tasks.)\n5.  **Your pet\'s secret life when you\'re not home.** (Are they throwing parties? Running a secret society? Judging your life choices?)\n6.  **Smart home devices that constantly misunderstand you.** (Alexa playing death metal when you asked for "smooth jazz.")\n7.  **The agony of trying to remember all your passwords.** (And the ridiculous security questions.)\n8.  **The "reply all" email chain that spirals out of control.** (Especially in a corporate setting.)\n9.  **Trying to open "child-proof" packaging when you\'re an adult.** (And failing miserably.)\n10. **The inner monologue of a pigeon.** (What are they *really* thinking as they stare at you?)\n11. **The endless scroll of streaming services and the inability to choose anything.** (Spending more time browsing than watching.)\n12. **People who talk on speakerphone in public.** (And the bizarre snippets of conversation you overhear.)\n\nChoose one that sparks your imagination! Good luck!', 'joke': 'Here\'s a joke about **Trying to open "child-proof" packaging when you\'re an adult**:\n\n"I\'m convinced \'child-proof\' packaging is actually \'adult-proof.\' My kids can open anything, but I need a search party and a pair of pliers just to get to the Advil."'}
# Next =  ('write_joke',)
# checkpoint ID =  1f0cbb8a-f632-60b0-8005-c7818e09e437
# -----
# {'topic': 'Okay, here are some funny topics for a joke, ranging from relatable to absurd:\n\n1.  **The existential dread of trying to assemble IKEA furniture.** (Universal frustration, tiny diagrams, missing screws, questioning your life choices.)\n2.  **Autocorrect fails that lead to hilariously inappropriate texts.** (Especially when texting parents or bosses.)\n3.  **Trying to explain technology to your parents/grandparents.** (The "where\'s the any key?" phenomenon, yelling at smart speakers.)\n4.  **The struggle of adulting:** bills, laundry, and pretending you know how to cook. (The sheer exhaustion of basic life tasks.)\n5.  **Your pet\'s secret life when you\'re not home.** (Are they throwing parties? Running a secret society? Judging your life choices?)\n6.  **Smart home devices that constantly misunderstand you.** (Alexa playing death metal when you asked for "smooth jazz.")\n7.  **The agony of trying to remember all your passwords.** (And the ridiculous security questions.)\n8.  **The "reply all" email chain that spirals out of control.** (Especially in a corporate setting.)\n9.  **Trying to open "child-proof" packaging when you\'re an adult.** (And failing miserably.)\n10. **The inner monologue of a pigeon.** (What are they *really* thinking as they stare at you?)\n11. **The endless scroll of streaming services and the inability to choose anything.** (Spending more time browsing than watching.)\n12. **People who talk on speakerphone in public.** (And the bizarre snippets of conversation you overhear.)\n\nChoose one that sparks your imagination! Good luck!', 'joke': 'Here\'s a joke about **Trying to open "child-proof" packaging when you\'re an adult**:\n\n"I\'m convinced \'child-proof\' packaging is actually \'adult-proof.\' My kids can open anything, but I need a search party and a pair of pliers just to get to the Advil."'}
# Next =  ('generate_topic',)
# checkpoint ID =  1f0cbb8a-9d11-6218-8004-f0c203e17bb4
# -----
# {'topic': 'Okay, here are some funny topics for a joke, ranging from relatable to absurd:\n\n1.  **The existential dread of trying to assemble IKEA furniture.** (Universal frustration, tiny diagrams, missing screws, questioning your life choices.)\n2.  **Autocorrect fails that lead to hilariously inappropriate texts.** (Especially when texting parents or bosses.)\n3.  **Trying to explain technology to your parents/grandparents.** (The "where\'s the any key?" phenomenon, yelling at smart speakers.)\n4.  **The struggle of adulting:** bills, laundry, and pretending you know how to cook. (The sheer exhaustion of basic life tasks.)\n5.  **Your pet\'s secret life when you\'re not home.** (Are they throwing parties? Running a secret society? Judging your life choices?)\n6.  **Smart home devices that constantly misunderstand you.** (Alexa playing death metal when you asked for "smooth jazz.")\n7.  **The agony of trying to remember all your passwords.** (And the ridiculous security questions.)\n8.  **The "reply all" email chain that spirals out of control.** (Especially in a corporate setting.)\n9.  **Trying to open "child-proof" packaging when you\'re an adult.** (And failing miserably.)\n10. **The inner monologue of a pigeon.** (What are they *really* thinking as they stare at you?)\n11. **The endless scroll of streaming services and the inability to choose anything.** (Spending more time browsing than watching.)\n12. **People who talk on speakerphone in public.** (And the bizarre snippets of conversation you overhear.)\n\nChoose one that sparks your imagination! Good luck!', 'joke': 'Here\'s a joke about **Trying to open "child-proof" packaging when you\'re an adult**:\n\n"I\'m convinced \'child-proof\' packaging is actually \'adult-proof.\' My kids can open anything, but I need a search party and a pair of pliers just to get to the Advil."'}
# Next =  ('__start__',)
# checkpoint ID =  1f0cbb8a-9d0e-6e77-8003-6daa696eb737
# -----
# {'topic': 'Okay, here are some funny topics for a joke, ranging from relatable to absurd:\n\n1.  **The existential dread of trying to assemble IKEA furniture.** (Universal frustration, tiny diagrams, missing screws, questioning your life choices.)\n2.  **Autocorrect fails that lead to hilariously inappropriate texts.** (Especially when texting parents or bosses.)\n3.  **Trying to explain technology to your parents/grandparents.** (The "where\'s the any key?" phenomenon, yelling at smart speakers.)\n4.  **The struggle of adulting:** bills, laundry, and pretending you know how to cook. (The sheer exhaustion of basic life tasks.)\n5.  **Your pet\'s secret life when you\'re not home.** (Are they throwing parties? Running a secret society? Judging your life choices?)\n6.  **Smart home devices that constantly misunderstand you.** (Alexa playing death metal when you asked for "smooth jazz.")\n7.  **The agony of trying to remember all your passwords.** (And the ridiculous security questions.)\n8.  **The "reply all" email chain that spirals out of control.** (Especially in a corporate setting.)\n9.  **Trying to open "child-proof" packaging when you\'re an adult.** (And failing miserably.)\n10. **The inner monologue of a pigeon.** (What are they *really* thinking as they stare at you?)\n11. **The endless scroll of streaming services and the inability to choose anything.** (Spending more time browsing than watching.)\n12. **People who talk on speakerphone in public.** (And the bizarre snippets of conversation you overhear.)\n\nChoose one that sparks your imagination! Good luck!', 'joke': 'Here\'s a joke about **Trying to open "child-proof" packaging when you\'re an adult**:\n\n"I\'m convinced \'child-proof\' packaging is actually \'adult-proof.\' My kids can open anything, but I need a search party and a pair of pliers just to get to the Advil."'}
# Next =  ()
# checkpoint ID =  1f0cbb89-f643-6b8f-8002-d069aefe1713
# -----
# {'topic': 'Okay, here are some funny topics for a joke, ranging from relatable to absurd:\n\n1.  **The existential dread of trying to assemble IKEA furniture.** (Universal frustration, tiny diagrams, missing screws, questioning your life choices.)\n2.  **Autocorrect fails that lead to hilariously inappropriate texts.** (Especially when texting parents or bosses.)\n3.  **Trying to explain technology to your parents/grandparents.** (The "where\'s the any key?" phenomenon, yelling at smart speakers.)\n4.  **The struggle of adulting:** bills, laundry, and pretending you know how to cook. (The sheer exhaustion of basic life tasks.)\n5.  **Your pet\'s secret life when you\'re not home.** (Are they throwing parties? Running a secret society? Judging your life choices?)\n6.  **Smart home devices that constantly misunderstand you.** (Alexa playing death metal when you asked for "smooth jazz.")\n7.  **The agony of trying to remember all your passwords.** (And the ridiculous security questions.)\n8.  **The "reply all" email chain that spirals out of control.** (Especially in a corporate setting.)\n9.  **Trying to open "child-proof" packaging when you\'re an adult.** (And failing miserably.)\n10. **The inner monologue of a pigeon.** (What are they *really* thinking as they stare at you?)\n11. **The endless scroll of streaming services and the inability to choose anything.** (Spending more time browsing than watching.)\n12. **People who talk on speakerphone in public.** (And the bizarre snippets of conversation you overhear.)\n\nChoose one that sparks your imagination! Good luck!'}
# Next =  ('write_joke',)
# checkpoint ID =  1f0cbb89-94e7-67a8-8001-4d19523aec9c
# -----
# {}
# Next =  ('generate_topic',)
# checkpoint ID =  1f0cbb89-3810-6579-8000-17e5a63da30d
# -----
# {}
# Next =  ('__start__',)
# checkpoint ID =  1f0cbb89-380d-6e77-bfff-3b37dd360770
# -----

# %% [markdown]
# Here are the checkpoint ids we got now lets take one checkpoint id to get started

# %%
selected_state = list(graph.get_state_history(config))[-3]

# %%
selected_state
# Out:
# StateSnapshot(values={'topic': 'Okay, here are some funny topics for a joke, ranging from relatable to absurd:\n\n1.  **The existential dread of trying to assemble IKEA furniture.** (Universal frustration, tiny diagrams, missing screws, questioning your life choices.)\n2.  **Autocorrect fails that lead to hilariously inappropriate texts.** (Especially when texting parents or bosses.)\n3.  **Trying to explain technology to your parents/grandparents.** (The "where\'s the any key?" phenomenon, yelling at smart speakers.)\n4.  **The struggle of adulting:** bills, laundry, and pretending you know how to cook. (The sheer exhaustion of basic life tasks.)\n5.  **Your pet\'s secret life when you\'re not home.** (Are they throwing parties? Running a secret society? Judging your life choices?)\n6.  **Smart home devices that constantly misunderstand you.** (Alexa playing death metal when you asked for "smooth jazz.")\n7.  **The agony of trying to remember all your passwords.** (And the ridiculous security questions.)\n8.  **The "reply all" email chain that spirals out of control.** (Especially in a corporate setting.)\n9.  **Trying to open "child-proof" packaging when you\'re an adult.** (And failing miserably.)\n10. **The inner monologue of a pigeon.** (What are they *really* thinking as they stare at you?)\n11. **The endless scroll of streaming services and the inability to choose anything.** (Spending more time browsing than watching.)\n12. **People who talk on speakerphone in public.** (And the bizarre snippets of conversation you overhear.)\n\nChoose one that sparks your imagination! Good luck!'}, next=('write_joke',), config={'configurable': {'thread_id': '8ed777e0-cbb8-11f0-89a1-b48c9d911a92', 'checkpoint_ns': '', 'checkpoint_id': '1f0cbb89-94e7-67a8-8001-4d19523aec9c'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-11-27T17:43:35.496285+00:00', parent_config={'configurable': {'thread_id': '8ed777e0-cbb8-11f0-89a1-b48c9d911a92', 'checkpoint_ns': '', 'checkpoint_id': '1f0cbb89-3810-6579-8000-17e5a63da30d'}}, tasks=(PregelTask(id='a834921d-f596-d76e-1f34-38ed2892bb0e', name='write_joke', path=('__pregel_pull', 'write_joke'), error=None, interrupts=(), state=None, result={'joke': 'Here\'s a joke about **Trying to open "child-proof" packaging when you\'re an adult**:\n\n"I\'m convinced \'child-proof\' packaging is actually \'adult-proof.\' My kids can open anything, but I need a search party and a pair of pliers just to get to the Advil."'}),), interrupts=())

# %% [markdown]
# Update the state of the selected state to run without rerunning the entire nodes

# %%
new_config= graph.update_state(selected_state.config,values={"topic":"computer"})
new_config
# Out:
# {'configurable': {'thread_id': '8ed777e0-cbb8-11f0-89a1-b48c9d911a92',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0cbb97-bc56-6bdc-8002-de08ba5d8cb6'}}

# %% [markdown]
# **Note:** In case if you want to update the messages you need to send the exact `id` to update the message.
#
# Resume the execution from the checkpoint. By Passing the New config to it. But it must contain  the same thread_id

# %%
async for chunk in graph.astream(None,new_config,stream_mode="updates"):
    print(chunk)
# Out:
# {'write_joke': {'joke': 'Why was the computer cold?\n\nBecause it left its Windows open!'}}
